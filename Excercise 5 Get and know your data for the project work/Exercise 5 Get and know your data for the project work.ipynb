# %%
import pandas as pd

chipo = pd.read_csv('topSubscribed.csv', delimiter=',', encoding='utf-8')

# %%
# %pwd
# Out:
# 'c:\\Users\\merik\\OneDrive - Hämeen ammattikorkeakoulu\\1Vuosi_Moduuli2\\Analysoinnin perusteet\\Harjoitusteht-v-t\\Excercise 5 Get and know your data for the project work'

# %%
chipo.head(10)
# Out:
#    Rank             Youtube Channel  Subscribers      Video Views Video Count  \
# 0     1                    T-Series  234,000,000  212,900,271,553      18,515
# 1     2              YouTube Movies  161,000,000                0           0
# 2     3  Cocomelon - Nursery Rhymes  152,000,000  149,084,178,448         846
# 3     4                   SET India  150,000,000  137,828,094,104     103,200
# 4     5                     MrBeast  128,000,000   21,549,128,785         733
# 5     6                       Music  118,000,000                0           0
# 6     7                   PewDiePie  111,000,000   28,851,883,250       4,694
# 7     8           ✿ Kids Diana Show  106,000,000   86,638,570,921       1,056
# 8     9                 Like Nastya  104,000,000   87,202,935,675         754
# 9    10                      Gaming   93,300,000                0           0
#
#                                             Category  Started
# ...

# %%
chipo.shape[0]
# Out:
# 1000

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             1000 non-null   int64
#  1   Youtube Channel  1000 non-null   object
#  2   Subscribers      1000 non-null   object
#  3   Video Views      1000 non-null   object
#  4   Video Count      1000 non-null   object
#  5   Category         1000 non-null   object
#  6   Started          1000 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB

# %%
chipo.shape
# Out:
# (1000, 7)

# %%
chipo.columns
# Out:
# Index(['Rank', 'Youtube Channel', 'Subscribers', 'Video Views', 'Video Count',
#        'Category', 'Started'],
#       dtype='object')

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
chipo.values
# Out:
# array([[1, 'T-Series', '234,000,000', ..., '18,515', 'Music', 2006],
#        [2, 'YouTube Movies', '161,000,000', ..., '0', 'Film & Animation',
#         2015],
#        [3, 'Cocomelon - Nursery Rhymes', '152,000,000', ..., '846',
#         'Education', 2006],
#        ...,
#        [998, 'YtCrash', '11,400,000', ..., '1', 'Education', 2015],
#        [999, 'Painzeiro', '11,400,000', ..., '946', 'People & Blogs',
#         2015],
#        [1000, 'Oum Walid', '11,400,000', ..., '1,598', 'People & Blogs',
#         2015]], shape=(1000, 7), dtype=object)

# %%
column_data_types = chipo.dtypes
print(column_data_types)
# Out:
# Rank                int64
# Youtube Channel    object
# Subscribers        object
# Video Views        object
# Video Count        object
# Category           object
# Started             int64
# dtype: object

# %%
column_data_type = chipo['Rank'].dtype
print(column_data_type)
# Out:
# int64

# %%
chipo.sort_values("Started")
# Out:
#      Rank   Youtube Channel Subscribers     Video Views Video Count  \
# 99    100           YouTube  35,200,000   2,980,922,779         620
# 22     23            Zee TV  65,400,000  31,291,572,708      80,178
# 507   508              VICE  16,500,000   4,417,232,834       3,786
# 68     69           Shakira  40,100,000  25,428,049,775         307
# 762   763               BBC  13,200,000   9,296,738,948      14,156
# ..    ...               ...         ...             ...         ...
# 487   488              SMOL  16,800,000  18,006,604,541       2,813
# 483   484        Azhan5star  16,800,000   8,351,014,001         507
# 587   588  Marta and Rustam  15,100,000  16,065,818,431         571
# 520   521       Sagawa /さがわ  16,200,000  13,685,363,296       4,602
# 983   984          ZutiGang  11,500,000  12,712,546,262       1,075
#
#             Category  Started
# 99   News & Politics     1970
# 22     Entertainment     2005
# 507    Entertainment     2005
# ...

# %%
chipo.sort_values("Started", ascending=False)
# Out:
#      Rank       Youtube Channel Subscribers     Video Views Video Count  \
# 400   401          Shorts Break  18,400,000  12,771,152,207         351
# 898   899            deepesh zo  12,100,000   5,655,945,454         392
# 853   854        Priyal Kukreja  12,500,000   7,984,381,092         613
# 587   588      Marta and Rustam  15,100,000  16,065,818,431         571
# 483   484            Azhan5star  16,800,000   8,351,014,001         507
# ..    ...                   ...         ...             ...         ...
# 70     71          Ishtar Music  39,500,000  16,198,667,693       4,582
# 335   336  Marvel Entertainment  20,000,000   5,423,946,266       8,257
# 903   904         Avril Lavigne  12,100,000   5,905,100,328         163
# 64     65               Rihanna  40,900,000  21,169,959,746          82
# 99    100               YouTube  35,200,000   2,980,922,779         620
#
#             Category  Started
# 400           Comedy     2021
# 898   People & Blogs     2021
# ...

# %%
chipo.sort_values(["Rank", "Started"])
# Out:
#      Rank             Youtube Channel  Subscribers      Video Views  \
# 0       1                    T-Series  234,000,000  212,900,271,553
# 1       2              YouTube Movies  161,000,000                0
# 2       3  Cocomelon - Nursery Rhymes  152,000,000  149,084,178,448
# 3       4                   SET India  150,000,000  137,828,094,104
# 4       5                     MrBeast  128,000,000   21,549,128,785
# ..    ...                         ...          ...              ...
# 995   996                     XO TEAM   11,500,000   11,471,384,709
# 996   997         Nirahua Music World   11,500,000    5,997,717,755
# 997   998                     YtCrash   11,400,000        3,825,084
# 998   999                   Painzeiro   11,400,000    2,143,444,281
# 999  1000                   Oum Walid   11,400,000    2,480,064,722
#
#     Video Count          Category  Started
# 0        18,515             Music     2006
# 1             0  Film & Animation     2015
# ...

# %%
chipo.sort_values(["Rank", "Started"], ascending=[False,True])
# Out:
#      Rank             Youtube Channel  Subscribers      Video Views  \
# 999  1000                   Oum Walid   11,400,000    2,480,064,722
# 998   999                   Painzeiro   11,400,000    2,143,444,281
# 997   998                     YtCrash   11,400,000        3,825,084
# 996   997         Nirahua Music World   11,500,000    5,997,717,755
# 995   996                     XO TEAM   11,500,000   11,471,384,709
# ..    ...                         ...          ...              ...
# 4       5                     MrBeast  128,000,000   21,549,128,785
# 3       4                   SET India  150,000,000  137,828,094,104
# 2       3  Cocomelon - Nursery Rhymes  152,000,000  149,084,178,448
# 1       2              YouTube Movies  161,000,000                0
# 0       1                    T-Series  234,000,000  212,900,271,553
#
#     Video Count          Category  Started
# 999       1,598    People & Blogs     2015
# 998         946    People & Blogs     2015
# ...

# %%
subset_chipo = chipo["Category"]
print(subset_chipo)
# Out:
# 0                 Music
# 1      Film & Animation
# 2             Education
# 3                 Shows
# 4         Entertainment
#              ...
# 995      People & Blogs
# 996               Music
# 997           Education
# 998      People & Blogs
# 999      People & Blogs
# Name: Category, Length: 1000, dtype: object

# %%
subset_chipo1 = chipo[["Rank", "Category", "Started"]]
print(subset_chipo1)
# Out:
#      Rank          Category  Started
# 0       1             Music     2006
# 1       2  Film & Animation     2015
# 2       3         Education     2006
# 3       4             Shows     2006
# 4       5     Entertainment     2012
# ..    ...               ...      ...
# 995   996    People & Blogs     2021
# 996   997             Music     2014
# 997   998         Education     2015
# 998   999    People & Blogs     2015
# 999  1000    People & Blogs     2015
#
# [1000 rows x 3 columns]

# %%
subset_df = chipo[chipo['Started'] > 2015]
print(subset_df)
# Out:
#      Rank  Youtube Channel  Subscribers     Video Views Video Count  \
# 8       9      Like Nastya  104,000,000  87,202,935,675         754
# 11     12    Vlad and Niki   92,700,000  72,444,118,381         520
# 13     14        BLACKPINK   83,900,000  28,723,286,185         468
# 15     16  5-Minute Crafts   78,500,000  24,983,430,208       5,937
# 51     52      BRIGHT SIDE   44,300,000  10,430,931,571       5,173
# ..    ...              ...          ...             ...         ...
# 975   976       Stray Kids   11,600,000   2,599,025,008         709
# 979   980      CarryisLive   11,600,000   1,449,647,680         947
# 983   984         ZutiGang   11,500,000  12,712,546,262       1,075
# 984   985         Flamingo   11,500,000   9,569,061,994       2,324
# 995   996          XO TEAM   11,500,000  11,471,384,709       2,679
#
#            Category  Started
# 8    People & Blogs     2016
# 11    Entertainment     2018
# 13   People & Blogs     2016
# 15    Howto & Style     2016
# ...

# %%
subset_df = chipo[chipo['Category'] == "Howto & Style"]
print(subset_df)
# Out:
#      Rank                      Youtube Channel Subscribers     Video Views  \
# 15     16                      5-Minute Crafts  78,500,000  24,983,430,208
# 51     52                          BRIGHT SIDE  44,300,000  10,430,931,571
# 124   125                               GENIAL  31,700,000   6,578,128,540
# 212   213                                 Yuya  24,900,000   2,586,211,373
# 225   226                           Chloe Ting  24,300,000   2,855,477,471
# 246   247                          Troom Troom  23,400,000  10,001,222,206
# 297   298                                Tasty  21,000,000   5,614,408,524
# 301   302                  5-Minute Crafts DIY  20,800,000   4,997,658,141
# 327   328                 5-Minute Crafts PLAY  20,100,000   5,916,449,403
# 329   330                        Gulshan Kalra  20,100,000   9,709,536,467
# 358   359              Village Cooking Channel  19,500,000   5,091,483,300
# ...
