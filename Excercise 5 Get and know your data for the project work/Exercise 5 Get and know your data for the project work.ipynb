# %%
import pandas as pd

chipo = pd.read_csv('topSubscribed.csv', delimiter=',', encoding='utf-8')

# %%
# %pwd
# Out:
# 'c:\\Users\\merik\\OneDrive - Hämeen ammattikorkeakoulu\\1Vuosi_Moduuli2\\Analysoinnin perusteet\\TopSubscribers'

# %%
chipo.columns
# Out:
# Index(['Rank', 'Youtube Channel', 'Subscribers', 'Video Views', 'Video Count',
#        'Category', 'Started'],
#       dtype='object')
