# %%
print("Printer App")
print("This app is made by:")
creator = "Meri"
print(creator)

#Alustetaan numerot
number1 = 10
number2 = 5

#Alustetaan laskutoimitukset
multiplication = number1 * number2
addition = number1 + number2
division = number1 - number2
substraction = number1 / number2

print(number1) #Tämä toimii

print("The value of number1 is" , number1)
print("The value of number2 is" , number2)

print(number1 , "*" , number2 , "=" , multiplication)
print(number1 , "+" , number2 , "=" , addition)
print(number1 , "-" , number2 , "=" , division)
print(number1 , "/" , number2 , "=" , substraction)
# Out:
# Printer App
# This app is made by:
# Meri
# 10
# The value of number1 is 10
# The value of number2 is 5
# 10 * 5 = 50
# 10 + 5 = 15
# 10 - 5 = 5
# 10 / 5 = 2.0
