# %%
import pandas as pd

chipo = pd.read_csv('topSubscribed.csv', delimiter=',', encoding='utf-8')

# %%
chipo1 = {'Category': ['People & Blogs', 'Music', 'Gaming'], 'Started': [2015, 2019, 2021]}
chipo1 = pd.DataFrame(chipo1)

chipo2 = {'Category': ['Howto & Style', 'Comedy', 'Entertaiment'], 'Started': [2016, 2018, 2020]}
chipo2 = pd.DataFrame(chipo2)

result = pd.concat([chipo1, chipo2])
print(result)
# Out:
#          Category  Started
# 0  People & Blogs     2015
# 1           Music     2019
# 2          Gaming     2021
# 0   Howto & Style     2016
# 1          Comedy     2018
# 2    Entertaiment     2020
